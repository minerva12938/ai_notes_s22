# %% [markdown]
# <a href="https://colab.research.google.com/github/minerva12938/ai_notes_s22/blob/main/decision_tree_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screen Shot 2022-07-15 at 10.31.09 AM.png](data:image/png;base64,...)

# %% [markdown]
# Basket - 4 marbles
# - color: red, blue, green, yellow
# - p(X = red) = 1/4
# - p(X1 = red, X2 = blue):
#   - with replacement: 1/4 * 1/4 = 1/16
#   - without: 1/4 * 1/3 = 1/12
#
# replacement
# - to generate/increase training samples
# - n training sample/training data
#
# how to use bootstrap sampling to overcome overfit in DT?
# - sampling multiple times 'b', sampling size 'n' < m
# - each construct DT using IG
#
# result: multiple DT tree
#
# how do we predict new data?
# - pick best tree? how do we know which one's best?
#   - accuracy? train/val
#   - doesn't guarantee to overcome because we are trying to overfit the train again
# - pick t number of trees?
#   - complex
# - pick all the trees? how to predict in this case?
#   - simplest
#
# bagging of decision tree
#
# algorithms:
# 1. generate boostrap samples
# 2. each sampling construct DT using IG
# 3. given new data, predict its output using majority vote[classification] or average[regression]
#
# disadvantage: using information gain, sampling might be closely similar
#
# subset size: k
#
#
# algorithm:
# - at each partition, choose a subset of attributes
# - use this subset to get max IG & construct the tree
#
# boosting
# - method to increase the ___ accuracy
#
# concept:
# - takes 'weak learner' and boost that to 'strong learner'
# - weak learner: have 50% accuracy on training data
#   - decision stump, perceptron?, high value of lamda
# - strong learner: have high accuracy on training data
#   - NN, DT, higher degree logistic/linear regression
